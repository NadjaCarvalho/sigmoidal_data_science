# %% [markdown]
# <a href="https://colab.research.google.com/github/NadjaCarvalho/sigmoidal_data_science/blob/master/Projeto_Nadja_Panorama_do_COVID_19_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 3.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # COVID-19 no Brasil
#
# Os primeiros casos da doença foram identificados na cidade de **Wuhan na China**.
# O vírus nunca havia sido identificado antes em seres humanos.
# A OMS foi alertada sobre os casos de coronavírus em *31 de dezembro de 2019*.
# Até o momento não se sabe o que realmente originou essa cepa.
# Como vírus, o contágio da doença é exponencial e medidas mundiais foram tomadas visando a desaceleração da contaminação.
# No Brasil não foi diferente, medidas restritivas foram tomadas de forma a mitigar os impactos da aceleração da contaminação.
#
#
#
# <center><img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/NadjaCarvalho/BancodeDados/main/wepik-2022113-14543.jpg"></center>
#
#
#
# Em grande parte da população os sintomas são leves e/ou não necessitam de internação, no entanto uma parcela da população exigem uma infraestrutura de saúde mais escassa e milhares de pessoas no mundo todo morreu em gravidade do vírus.
#
# A vacinação chegou ao Brasil em janeiro de 2021; na primeira fase foram priorizados idosos e profissionais da área de saúde, pois trabalhavam diretamente no combate à pandemia.
#
#
# Passado dois anos do início da pandemia, estarei realizando uma análise dos dados públicos da covid 19 no Brasil.

# %% [markdown]
# ## Obtenção dos Dados
#
# *Os dados aqui analisados foram extraídos do site https://github.com/owid/covid-19-data/tree/master/public/data. Serão analisados o cenário mundial de casos de COVID 19, com os 5 primeiros países com mais mortes.*
# *Será analisado quando foi identificado o primeiro caso de covid no Brasil, quanto tempo demorou para registrar a primeira morte.*
#
#
# *Dados de saúde numa realidade de pandemia, no cenário de um vírus desconhecido e com sintomas semelhantes a outros vírus conhecidos, inicialmente confundiu a muitos, inclusive a área médica.*
# *Sobre o aspecto dos impactos na economia e pontos de vistas diferentes dos dirigentes dos governos, claros para todos que acompanharam/ acompanham as informações que circulam. Analisar dados nesse cenário não é fácil.*
#
#
# ### Dicionário de Variáveis
# * *Variáveis.*
#     * `iso_code` - Código dos países
#     * `continent`- Continente
#     * `location`- Localização geográfica
#     * `date`- Data
#     * `total_cases`- Total de casos
#     * `new_cases`- Novos casos
#     * `new_cases_smoothed`- Novos casos confirmados
#     * `total_deaths`- Total de mortes
#     * `new_deaths`- Novas mortes
#     * `new_deaths_smoothed`- Novas mortes confirmadas
#     * `total_cases_per_million`- Total de casos/ milhão
#     * `new_cases_per_million`- Novos casos por milhão
#     * `new_cases_smoothed_per_million` - Novos casos confirmados de COVID-19 (suavizado em 7 dias) por 1.000.000 de pessoas. As contagens podem incluir casos prováveis, quando relatados.
#     * `total_deaths_per_million`-Total de mortes/ milhão
#     * `new_deaths_per_million`- Novas mortes/ milhão
#     * `new_deaths_smoothed_per_million`- Novas mortes atribuídas ao COVID-19 (suavizado de 7 dias) por milhão de pessoas
#     * `reproduction_rate`- Estimativa em tempo real da taxa efetiva de reprodução (R) do COVID-19
#     * `icu_patients`- Nº de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia
#     * `icu_patients_per_million`- pacientes de UTI por milhão
#     * `hosp_patients`- Nº de pacientes com COVID-19 no hospital em um determinado dia
#     * `hosp_patients_per_million`- Nº de pacientes com COVID-19 no hospital em um determinado dia / milhão de pessoas
#     * `weekly_icu_admissions`- Nº de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana
#     * `weekly_icu_admissions_per_million`- Número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana por 1.000.000 de pessoas
#     * `weekly_hosp_admissions`-Nº de pacientes com COVID-19 recém-admitidos em hospitais em uma determinada semana
#     * `weekly_hosp_admissions_per_million`-
# Número de pacientes com COVID-19 recém-admitidos em hospitais em uma determinada semana por 1.000.000 de pessoas
#     * `total_tests`- Total de testes para covid 19
#     * `new_tests`- Novos testes para COVID-19 (calculado apenas para dias consecutivos)
#     * `total_tests_per_thousand`- Total de testes para covid 19 por mil
#     * `new_tests_per_thousand`- Novos testes para covid 19 por mil
#     * `new_tests_smoothed`- Novos testes para COVID-19 (suavizado de 7 dias). Para países que não relatam dados de teste diariamente, assumimos que os testes mudaram igualmente diariamente em todos os períodos em que nenhum dado foi relatado. Isso produz uma série completa de números diários, que são então calculados em uma janela contínua de 7 dias
#     * `new_tests_smoothed_per_thousand`- Novos testes para COVID-19 (suavizado de 7 dias) por 1.000 pessoas
#     * `positive_rate`- A parcela de testes COVID-19 positivos, dada como uma média contínua de 7 dias
#     * `tests_per_case`- Testes realizados por novo caso confirmado de COVID-19, dados como uma média contínua de 7 dias
#     * `tests_units`- Unidades usadas pelo local para relatar seus dados de teste
#     * `total_vaccinations`- Nº total de doses de vacinação COVID-19 administradas
#     * `people_vaccinated`- Nº total de pessoas que receberam pelo menos uma dose de vacina
#     * `people_fully_vaccinated`- Nº total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação inicial
#     * `total_boosters`- Número total de doses de reforço de vacinação COVID-19 administradas (doses administradas além do número prescrito pelo protocolo de vacinação)
#     * `new_vaccinations`- Novas doses de vacinação COVID-19 administradas (calculadas apenas para dias consecutivos)
#     * `new_vaccinations_smoothed`- Novas doses de vacinação COVID-19 administradas (suavizado por 7 dias). Para países que não relatam dados de vacinação diariamente, assumimos que a vacinação mudou igualmente diariamente em todos os períodos em que nenhum dado foi relatado. Isso produz uma série completa de números diários, que são então calculados em uma janela contínua de 7 dias
#     * `total_vaccinations_per_hundred`- Número total de doses de vacinação COVID-19 administradas por 100 pessoas na população total
#     * `people_vaccinated_per_hundred`- Número total de pessoas que receberam pelo menos uma dose de vacina por 100 pessoas na população total
#     * `people_fully_vaccinated_per_hundred`- Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação inicial por 100 pessoas na população total
#     * `total_boosters_per_hundred`- Número total de doses de reforço de vacinação COVID-19 administradas por 100 pessoas na população total
#     * `new_vaccinations_smoothed_per_million`- Novas doses de vacinação COVID-19 administradas (suavizadas em 7 dias) por 1.000.000 de pessoas na população total
#     * `new_people_vaccinated_smoothed`- Número diário de pessoas que recebem sua primeira dose de vacina (suavizado de 7 dias)
#     * `new_people_vaccinated_smoothed_per_hundred`- Número diário de pessoas que recebem sua primeira dose de vacina (suavizado de 7 dias) por 100 pessoas na população total
#     * `stringency_index`- Índice de Rigidez de Resposta do Governo: medida composta com base em 9 indicadores de resposta, incluindo fechamento de escolas, fechamento de locais de trabalho e proibição de viagens, reescalonado para um valor de 0 a 100 (100 = resposta mais rigorosa)
#     * `population`- População (últimos valores disponíveis). Consulte https://github.com/owid/covid-19-data/blob/master/scripts/input/un/population_latest.csv para obter a lista completa de fontes
#     * `population_density`- Número de pessoas dividido por área de terra, medido em quilômetros quadrados, ano mais recente disponível
#     * `median_age`- Idade média da população, projeção da ONU para 2020
#     * `aged_65_older`- Parcela da população com 65 anos ou mais, ano mais recente disponível
#     * `aged_70_older`- Parcela da população com 70 anos ou mais, ano mais recente disponível
#     * `gdp_per_capita`- Produto interno bruto em paridade de poder de compra (dólares internacionais constantes de 2011), ano mais recente disponível
#     * `extreme_poverty`- Percentual da população que vive em extrema pobreza, ano mais recente disponível desde 2010
#     * `cardiovasc_death_rate`- Taxa de mortalidade por doença cardiovascular em 2017 (número anual de mortes por 100.000 pessoas)
#     * `diabetes_prevalence`- Prevalência de diabetes (% da população de 20 a 79 anos) em 2017
#     * `female_smokers`- Proporção de mulheres que fumam, ano mais recente disponível
#     * `male_smokers`- Proporção de homens que fumam, ano mais recente disponível
#     * `handwashing_facilities`- Percentagem da população com instalações básicas de lavagem das mãos nas instalações, ano mais recente disponível
#     * `hospital_beds_per_thousand`- Hospital beds per 1,000 people, most recent year available since 2010
#     * `life_expectancy`- Expectativa de vida ao nascer em 2019
#     * `human_development_index`- Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano – uma vida longa e saudável, conhecimento e um padrão de vida decente. Valores para 2019
#     * `excess_mortality`- Diferença percentual entre o número relatado de mortes semanais ou mensais em 2020-2021 e o número projetado de mortes para o mesmo período com base em anos anteriores. Para obter mais informações, consulte https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
#     * `excess_mortality_cumulative`- Diferença percentual entre o número acumulado de mortes desde 1 de janeiro de 2020 e as mortes cumulativas projetadas para o mesmo período com base em anos anteriores. Para obter mais informações, consulte https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
#     * `excess_mortality_cumulative_absolute`- Diferença cumulativa entre o número relatado de óbitos desde 1º de janeiro de 2020 e o número projetado de óbitos para o mesmo período com base em anos anteriores. Para obter mais informações, consulte https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
#     * `excess_mortality_cumulative_per_million`- Diferença cumulativa entre o número relatado de mortes desde 1º de janeiro de 2020 e o número projetado de mortes para o mesmo período com base em anos anteriores, por milhão de pessoas. Para obter mais informações, consulte https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality

# %%
# importar as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_style()
# %matplotlib inline


# importar o dataset COVID-19 para um DataaFrame

covid="https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
df= pd.read_csv(covid, parse_dates=True)

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# * Estarei analisando o tamanho do Dataframe, suas variáveis e identificação de valores ausentes que pudessem comprometer a análise.
#
# * Os tipos de variáveis também serão analisados, verificando seus formatos e o comprometimento com os dados analisados.
#
# * Analisar a data mais atual do Dataframe e verificar o ranking dos 5 primeiros países com maiores casos de morte por  covid 19.
#
# * Criar um DataFrame apenas do Brasil para analisar a data em que aconteceu o primeiro caso de covid e quanto tempo depois disso, foi registrado a primeira morte.
#
# * Gráficos serão gerados para melhor compreensão dos dados.

# %% [markdown]
# ### Análise exploratória inicial

# %%
#Visualizar as 5 primeiras entradas do dataset
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
# Tamanho do dataframe
df.shape
# Out:
# (169091, 67)

# %%
# Extrair e imprimir os nomes das colunas
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
# Analisando o tipo das variáveis
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# human_development_index                    float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# A variável Date não está no formato mais interessante para exploração de dados, dessa forma será necessário transformar em DATETIME.

# %%
#Transformando a coluna date no formato datelime
df.date=pd.to_datetime(df.date)

# %%
#Identificando a porcentagem de valores ausentes das colunas
round((df.isnull().sum()/df.shape[0]).sort_values(ascending=False),2)
# Out:
# weekly_icu_admissions_per_million          0.97
# weekly_icu_admissions                      0.97
# excess_mortality_cumulative_per_million    0.97
# excess_mortality                           0.97
# excess_mortality_cumulative                0.97
#                                            ...
# total_cases                                0.02
# population                                 0.01
# date                                       0.00
# location                                   0.00
# iso_code                                   0.00
# Length: 67, dtype: float64

# %% [markdown]
# Em relação ao dataframe os valores ausentes para as variáveis que serão analisadas tem baixa representatividade de valores ausentes.

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.660290e+05  1.658790e+05        1.638830e+05  1.480850e+05
# mean   2.634551e+06  1.192975e+04        1.190505e+04  5.867857e+04
# std    1.614308e+07  8.657122e+04        8.446580e+04  3.072658e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.079000e+03  1.000000e+00        7.000000e+00  8.200000e+01
# 50%    2.730100e+04  7.900000e+01        1.078570e+02  7.970000e+02
# 75%    3.084200e+05  1.072000e+03        1.164215e+03  7.426000e+03
# max    4.662582e+08  4.115815e+06        3.445531e+06  6.065477e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  148130.000000        146011.000000            165259.000000
# mean      170.170668           171.808731             31000.319264
# std       828.245867           813.404381             55476.168869
# min         0.000000             0.000000                 0.001000
# ...

# %%
# Verificando a data mais recente do dataset
df.date.max()
# Out:
# Timestamp('2022-02-12 00:00:00')

# %% [markdown]
# A data mais recente do dataset é 12/02/2022

# %%
# Verificando quais países tem mais casos de morte atualmente

df.loc[df.date =='2022-02-12'].sort_values(by="total_cases", ascending=False)[:6]
df.loc[df.date =='2022-02-12'].sort_values(by="total_deaths", ascending=False)[:6]
# Out:
#         iso_code continent             location       date  total_cases  \
# 166892  OWID_WRL       NaN                World 2022-02-12  410471795.0
# 161369  OWID_UMC       NaN  Upper middle income 2022-02-12  110987158.0
# 67778   OWID_HIC       NaN          High income 2022-02-12  218549562.0
# 50889   OWID_EUR       NaN               Europe 2022-02-12  144920267.0
# 113910  OWID_NAM       NaN        North America 2022-02-12   91243194.0
# 9018    OWID_ASI       NaN                 Asia 2022-02-12  108158909.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 166892  1826616.0         2378402.571     5813203.0      8675.0
# 161369   661511.0          659259.429     2383367.0      4240.0
# 67778    950479.0         1480501.857     2134446.0      2667.0
# 50889    935585.0         1290217.571     1662680.0      2726.0
# 113910   129180.0          227117.143     1339887.0      2108.0
# 9018     510879.0          587118.000     1323032.0      1897.0
#
# ...

# %%
#Gráfico de barras com 5 países com mais número de mortes

top5_total_deaths=df.loc[df.date == '2022-02-11', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[1:6]

fig, ax = plt.subplots (figsize=(12,6))

ax.bar('location', 'total_deaths', data=top5_total_deaths)
ax.set_title ("Países com mais casos de morte por covid 19")
ax.set_xlabel("location")
ax.set_ylabel("total_deaths")

plt.tight_layout()

# %% [markdown]
# Na data mais recente do datraframe, 12/02/2022, os 5 países com mais casos de morte no mundo foram:
# * Upper middle com 2383367.0
# * High income com 2134446.0
# * Europe Location com 1662680.0
# * North America com 1339887.0
# * Asia com 1323032.0

# %%
#Evolução total de casos de morte no mundo

df.loc[df.location == "World", "total_deaths"].reset_index(drop=True).plot(figsize=(12,5));

# %% [markdown]
# ### Análise Exploratória para o Brasil
#
# **Vamos analisar os casos de covid 19 no Brasil.**

# %%
df_brasil= df.loc[df.location=="Brazil"].copy()

df_brasil.head()
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 21652      BRA  South America   Brazil 2020-02-26          1.0        1.0
# 21653      BRA  South America   Brazil 2020-02-27          1.0        0.0
# 21654      BRA  South America   Brazil 2020-02-28          1.0        0.0
# 21655      BRA  South America   Brazil 2020-02-29          2.0        1.0
# 21656      BRA  South America   Brazil 2020-03-01          2.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 21652                 NaN           NaN         NaN                  NaN  ...
# 21653                 NaN           NaN         NaN                  NaN  ...
# 21654                 NaN           NaN         NaN                  NaN  ...
# 21655                 NaN           NaN         NaN                  NaN  ...
# 21656                 NaN           NaN         NaN                  NaN  ...
#
# ...

# %%
df_brasil.shape
# Out:
# (718, 67)

# %%
df_brasil.date.max()
# Out:
# Timestamp('2022-02-12 00:00:00')

# %%
df_brasil.date.min()
# Out:
# Timestamp('2020-02-26 00:00:00')

# %%
#Primeira morte no Brasil

df_brasil.loc[df_brasil['new_deaths']==1.0].head(1)
# Out:
#       iso_code  ... excess_mortality_cumulative_per_million
# 20693      BRA  ...                                     NaN
#
# [1 rows x 67 columns]

# %%
df_brasil.loc[df_brasil['new_cases']==1.0].head(1)
# Out:
#       iso_code  ... excess_mortality_cumulative_per_million
# 20673      BRA  ...                                     NaN
#
# [1 rows x 67 columns]

# %% [markdown]
# #### O primeiro caso de covid registrado no Brasil aconteceu em 26.02.2020, a primeira morte aconteceu em 17.03.2020, ou seja, 20 dias após o primeiro caso registrado no país.

# %%
df_brasil.describe()
# Out:
#         total_cases  ...  excess_mortality_cumulative_per_million
# count  7.180000e+02  ...                                24.000000
# mean   1.134416e+07  ...                              1628.091567
# std    8.476197e+06  ...                              1206.838555
# min    1.000000e+00  ...                                32.943066
# 25%    3.614337e+06  ...                               607.129122
# 50%    1.006588e+07  ...                              1272.958642
# 75%    2.041580e+07  ...                              2895.248668
# max    2.743429e+07  ...                              3421.537112
#
# [8 rows x 62 columns]

# %% [markdown]
# ####Sobre o cenário de casos e morte no Brasil, o número máximo registrado de morte por dia, foi de 4.148, a média de mortes diária de 914.53. Até a data 12/02/2022, 638.346 mil pessoas morreram por covid 19 no Brasil.

# %%
x = list(range(718))
z = df_brasil["total_cases"]
z2 = df_brasil["total_deaths"]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(9, 7))
ax1.set_title("Casos no Brasil")
ax1.set_xlabel("Dias")
ax1.set_ylabel("Casos")
ax1.plot(x, z)

ax2.set_title("Casos no Brasil (Escala logarítmica)")
ax2.set_xlabel("Dias")
ax2.set_ylabel("Casos")
ax2.set_yscale("log")
ax2.plot(x, z)

ax3.set_title("Mortes no Brasil")
ax3.set_xlabel("Dias")
ax3.set_ylabel("Mortes")
ax3.plot(x, z2)

ax4.set_title("Mortes no Brasil (Escala logarítmica")
ax4.set_xlabel("Dias")
ax4.set_ylabel("Mortes")
ax4.set_yscale("log")
ax4.plot(x, z2)





plt.tight_layout()

# %% [markdown]
# Os gráficos mostram uma crescente nos **casos de morte no Brasil** ao longo do tempo.

# %% [markdown]
# ## Conclusão
#
# *A covid de forma geral continua em um número expressivo com o aparecimento de novas cepas ou variantes do vírus, menos letais, porém mais contagiosas.*
#
# *No Brasil o primeiro caso foi registrado em 26.02.2020 e após 20 dias, a primeira morte foi registrada.*
#
# *Até a data de 12.02.22, morreram no Brasil, 638.346 mil pessoas.*
#
# *A média diária de mortes estava em 914.53/ dia.*
#
# *No mundo, o Brasil é 11º país com mais casos de morte.*
